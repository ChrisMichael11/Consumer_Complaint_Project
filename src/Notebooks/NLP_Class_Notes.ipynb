# %%
import pandas as pd
import numpy as np
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

from nltk.stem.porter import PorterStemmer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer

from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer

from sklearn.metrics.pairwise import linear_kernel

# %%
df = pd.read_csv('../data/Consumer_Complaints_with_Consumer_Complaint_Narratives.csv')

# %%
def create_df_text(df):
    df_text = pd.DataFrame()  # Create empty df to fill
    
    df_text['Consumer complaint narrative'] = df['Consumer complaint narrative']
    
    cust_resp_dict ={'Closed':0,
                 'Untimely response':0,
                 'Closed with explanation':1,
                 'Closed with non-monetary relief':2,
                 'Closed with monetary relief':2}
    
    df_text['Company response to consumer'] = df['Company response to consumer'].apply(lambda x: cust_resp_dict[x])
    
    return df_text

# %%
df_text = create_df_text(df).head()

# %%
tokenized = [word_tokenize(content.lower()) for content in df_text['Consumer complaint narrative']]

# %%
stop = set(stopwords.words('english'))

# %%
docs = [[word for word in words if word not in stop] for words in tokenized]

# %%
docs
# Out:
# [['received',
#   'capital',
#   'one',
#   'charge',
#   'card',
#   'offer',
#   'xxxx',
#   '.',
#   'applied',
#   ',',
#   'accepted',
#   '(',
#   '{',
#   '$',
#   '500.00',
#   '}',
#   'limit',
#   ')',
#   ',',
#   'activated',
#   'card',
#   'used',
#   'xxxx',
#   'presents',
#   '.',
#   'charge',
#   'card',
#   '#',
#   'xxxx',
#   '.',
#   'right',
#   'activating',
#   'card',
#   '...',
#   'capital',
#   'one',
#   'sent',
#   'another',
#   'card',
#   '{',
#   '$',
#   '500.00',
#   '}',
#   'limit',
#   '...',
#   'never',
#   'activated',
#   '...',
#   'never',
#   'used',
#   'card',
#   '.',
#   'first',
#   'bill',
#   'card',
#   '#',
#   'came',
#   'due',
#   'xxxx',
#   'minimum',
#   'payment',
#   'due',
#   '{',
#   '$',
#   '15.00',
#   '}',
#   '.',
#   'sent',
#   '{',
#   '$',
#   '20.00',
#   '}',
#   'via',
#   'uspmo',
#   'sent',
#   'due',
#   'date',
#   '.',
#   'xxxx',
#   'non-activated',
#   ',',
#   'non',
#   'used',
#   'credit',
#   'card',
#   '...',
#   '..they',
#   'also',
#   'sent',
#   'bill',
#   'yearly',
#   'fees',
#   'never',
#   'even',
#   'activated',
#   'card',
#   '.',
#   'called',
#   '...',
#   '...',
#   '.told',
#   'want',
#   'card',
#   'sent',
#   'back',
#   '.',
#   'well',
#   '...',
#   '.get',
#   'next',
#   'bill',
#   'card',
#   '#',
#   '(',
#   'xxxx',
#   ')',
#   '...',
#   '.they',
#   'credit',
#   '{',
#   '$',
#   '20.00',
#   '}',
#   'payment',
#   'charged',
#   'outrageous',
#   'limit',
#   'fees',
#   ',',
#   'late',
#   'fees',
#   ',',
#   'etc',
#   '...',
#   '{',
#   '$',
#   '70.00',
#   '}',
#   'payment',
#   'due',
#   '.',
#   ',',
#   'called',
#   ',',
#   'rep',
#   'stated',
#   'accidentally',
#   'applied',
#   '{',
#   '$',
#   '20.00',
#   '}',
#   'payment',
#   'wrong',
#   'account',
#   'number',
#   'would',
#   'corrected',
#   '.',
#   ',',
#   'sent',
#   '{',
#   '$',
#   '70.00',
#   '}',
#   'payment',
#   'via',
#   'uspmo',
#   'along',
#   'note',
#   'make',
#   'sure',
#   'account',
#   'corrected',
#   'payments',
#   'applied',
#   'correct',
#   'account',
#   'number',
#   '(',
#   'minimum',
#   'due',
#   'wanted',
#   'keep',
#   'card',
#   'also',
#   'repair',
#   'credit',
#   'bankruptcy',
#   'xxxx',
#   'xxxx.',
#   ')',
#   '...',
#   'xxxx',
#   'bill',
#   'came',
#   'mail',
#   '...',
#   '.and',
#   '...',
#   '..they',
#   'apply',
#   'payment',
#   '{',
#   '$',
#   '70.00',
#   '}',
#   ',',
#   'previous',
#   'payment',
#   '{',
#   '$',
#   '20.00',
#   '}',
#   '...',
#   '.which',
#   'stated',
#   'would',
#   'correct',
#   '.',
#   'charged',
#   'outrageous',
#   'limit',
#   'fees',
#   ',',
#   'late',
#   'fees',
#   ',',
#   'etc',
#   ',',
#   'along',
#   'stupid',
#   'note',
#   '``',
#   'spreading',
#   'thin.',
#   "''",
#   'thought',
#   'wow',
#   '...',
#   '.this',
#   'total',
#   'bs',
#   '...',
#   '..so',
#   'called',
#   'numerous',
#   'times',
#   ',',
#   'wrote',
#   'numerous',
#   'times',
#   '...',
#   'success',
#   'correcting',
#   'account',
#   ',',
#   'acknowledged',
#   'mistake',
#   '(',
#   ')',
#   '...',
#   '...',
#   'wanted',
#   '{',
#   '$',
#   '120.00',
#   '}',
#   'minimum',
#   'payment',
#   '...',
#   '.i',
#   'thought',
#   'totally',
#   'illegal',
#   '.',
#   'sent',
#   'payments',
#   'time',
#   'sent',
#   'minimum',
#   'even',
#   'begin',
#   '.',
#   'kept',
#   'calling',
#   'writing',
#   ',',
#   'resolution',
#   'like',
#   'stated',
#   '.',
#   'totally',
#   'quit',
#   'paying',
#   'point',
#   '...',
#   'know',
#   'else',
#   'time',
#   '.',
#   'sometime',
#   'around',
#   'end',
#   'xxxx',
#   'started',
#   'getting',
#   'threatening',
#   'phone',
#   'calls',
#   'collection',
#   'agency',
#   '...',
#   '...',
#   'mean',
#   'really',
#   'threatening',
#   '.',
#   'like',
#   'every',
#   'day',
#   '.',
#   'well',
#   ',',
#   'ended',
#   'extremely',
#   'ill',
#   ',',
#   'hospitals',
#   'around',
#   'time',
#   ',',
#   'doctors',
#   ',',
#   'hospitals',
#   ',',
#   'xxxx',
#   ',',
#   'xxxx',
#   ',',
#   'xxxx',
#   '...',
#   '..etc',
#   '...',
#   '..ended',
#   'xxxx',
#   'xxxx',
#   'entire',
#   'summer',
#   ',',
#   'due',
#   'xxxx',
#   ',',
#   'xxxx',
#   '(',
#   'xxxx',
#   'time',
#   ')',
#   'xxxx',
#   '...',
#   'xxxx',
#   ',',
#   'xxxx',
#   ',',
#   '(',
#   'records.',
#   ')',
#   'anyway',
#   '...',
#   'come',
#   'xxxx',
#   'xxxx',
#   ',',
#   'xxxx',
#   ',',
#   'xxxx',
#   ',',
#   'xxxx',
#   'put',
#   'freeze',
#   'bank',
#   'account',
#   '.',
#   '(',
#   'currently',
#   'xxxx',
#   'xxxx',
#   '...',
#   'never',
#   'knew',
#   'took',
#   'court',
#   '&',
#   'illegal',
#   'judgement',
#   '.',
#   'called',
#   'capital',
#   'one',
#   '...',
#   'new',
#   'nothing',
#   '...',
#   'called',
#   'xxxx',
#   'etc..asked',
#   'verification',
#   'xxxx',
#   'xxxx',
#   ')',
#   ',',
#   'etc..of',
#   'account',
#   ',',
#   'payments',
#   ',',
#   'court',
#   'order',
#   ',',
#   'etc',
#   '.',
#   'receive',
#   'back',
#   'info',
#   'account',
#   '.',
#   'clearly',
#   'shows',
#   'put',
#   'minimum',
#   'payments',
#   'onto',
#   'totally',
#   'different',
#   'account',
#   '...',
#   '..i',
#   'proof',
#   ',',
#   'illegal',
#   'practices',
#   'regarding',
#   'capital',
#   'one',
#   'xxxx',
#   ',',
#   'xxxx',
#   'xxxx',
#   '.',
#   'also',
#   'stubs',
#   'payments',
#   'sent',
#   'via',
#   'uspmo',
#   'proof',
#   '.',
#   ',',
#   'recently',
#   'calls',
#   'home',
#   'unknown',
#   'number',
#   'stating',
#   'call',
#   'xxxx',
#   'stating',
#   'something',
#   'effect',
#   '(',
#   'name',
#   ')',
#   '``',
#   'property',
#   '(',
#   'home',
#   ')',
#   'address',
#   "''",
#   'sent',
#   'clerks',
#   'office',
#   '.',
#   'mother',
#   ',',
#   'owner',
#   'home',
#   ',',
#   'also',
#   'getting',
#   'calls',
#   'days',
#   'row',
#   '...',
#   'regarding',
#   '``',
#   'property',
#   '(',
#   'home',
#   'address.',
#   ')',
#   'clerk',
#   'court',
#   '.',
#   'owner',
#   'home',
#   'rent',
#   '...',
#   'property',
#   'nothing',
#   'capital',
#   'one',
#   'account',
#   'totally',
#   'illegally',
#   'screwed',
#   'on..along',
#   'xxxx',
#   ',',
#   'xxxx',
#   'xxxx',
#   'xxxx',
#   'illegal',
#   'collection',
#   'practices',
#   '.',
#   ',',
#   'look',
#   'website',
#   ',',
#   'attorney',
#   'xxxx',
#   ',',
#   'xxxx',
#   ',',
#   'xxxx',
#   'judgement',
#   'renewal',
#   'previous',
#   'us',
#   'getting',
#   'harassing',
#   ',',
#   'threatening',
#   ',',
#   'illegal',
#   'calls',
#   '.',
#   'need',
#   'help',
#   '.'],
#  ["n't",
#   'know',
#   'got',
#   'cell',
#   'number',
#   '.',
#   'told',
#   'would',
#   'deal',
#   'onlybwith',
#   'original',
#   'company',
#   'stop',
#   'harassing',
#   '.',
#   'called',
#   'sending',
#   'contact',
#   'messsage',
#   'told',
#   'would',
#   'report',
#   '.',
#   'contacted',
#   'people',
#   'whose',
#   'concern',
#   'business',
#   '.'],
#  ["'m",
#   'longtime',
#   'member',
#   'charter',
#   'one',
#   'bank/rbs',
#   'citizens',
#   'bank',
#   '.',
#   'mother',
#   ';',
#   'xxxx',
#   'xxxx',
#   'became',
#   'elderly',
#   ',',
#   'assisted',
#   'opening',
#   'account',
#   'charter',
#   'one',
#   'branch',
#   'office',
#   'located',
#   'xxxx',
#   'xxxx',
#   'xxxx',
#   'xxxx',
#   'xxxx',
#   ',',
#   'michigan',
#   'placed',
#   'account',
#   'co-account',
#   'owner',
#   '.',
#   'mother',
#   "'s",
#   'xxxx',
#   ',',
#   'became',
#   'necessary',
#   'obtain',
#   '``',
#   'durable',
#   'power',
#   'attorney',
#   "''",
#   'handle',
#   'financial',
#   'medical',
#   'needs',
#   '.',
#   'years',
#   'ago',
#   ',',
#   'mother',
#   'present',
#   ',',
#   'presented',
#   'original',
#   '(',
#   'stamped',
#   'seal',
#   ')',
#   '``',
#   'durable',
#   'power',
#   'attorney',
#   "''",
#   'charter',
#   'one',
#   'branch',
#   'office',
#   'located',
#   'xxxx',
#   'xxxx',
#   ',',
#   'michigan',
#   'record',
#   'file',
#   '.',
#   'presented',
#   ',',
#   'understanding',
#   'would',
#   'placed',
#   'mother',
#   "'s",
#   'account',
#   '.',
#   'furthermore',
#   ',',
#   'needed',
#   'transact',
#   'business',
#   'would',
#   'welcomed',
#   'though',
#   '``',
#   "''",
#   '``',
#   'she.',
#   "''",
#   'xxxx',
#   'xxxx',
#   ',',
#   '2015',
#   ',',
#   'contacted',
#   'charter',
#   'one',
#   'master',
#   'card',
#   'someone',
#   'made',
#   'fraudulent',
#   'charges',
#   'mother',
#   "'s",
#   'credit',
#   'card',
#   'account',
#   '.',
#   'caller',
#   'stated',
#   'would',
#   'immediately',
#   'close',
#   'mother',
#   "'s",
#   'master',
#   'credit',
#   'card',
#   'account',
#   'open',
#   'new',
#   'account',
#   'send',
#   'another',
#   'master',
#   'card',
#   'next',
#   'day',
#   '.',
#   'upon',
#   'receiving',
#   'mother',
#   "'s",
#   'new',
#   'credit',
#   'card',
#   'realized',
#   'entitled',
#   '``',
#   'xxxx',
#   "''",
#   'bonus',
#   'points',
#   '.',
#   'telephoned',
#   'bank',
#   'redeem',
#   '``',
#   'xxxx',
#   'xxxx',
#   "''",
#   'bonus',
#   'points',
#   'informed',
#   'name',
#   'mother',
#   "'s",
#   'credit',
#   'card',
#   'account',
#   '.',
#   'informed',
#   ',',
#   'taken',
#   'original',
#   '``',
#   'durable',
#   'power',
#   'attorney',
#   "''",
#   'branch',
#   'office',
#   'file',
#   '.',
#   'representative',
#   'indicated',
#   '``',
#   'durable',
#   'power',
#   'attorney',
#   "''",
#   'file',
#   'charter',
#   'one',
#   'bank',
#   'master',
#   'card',
#   'separate',
#   'entity',
#   'bank',
#   'would',
#   'require',
#   'another',
#   '``',
#   'durable',
#   'power',
#   'attorney.',
#   "''",
#   'replied',
#   'ca',
#   "n't",
#   'charter',
#   'one',
#   'forward',
#   'copy',
#   '``',
#   'durable',
#   'power',
#   'attorney',
#   "''",
#   'master',
#   'card',
#   '.',
#   'told',
#   'go',
#   'local',
#   'branch',
#   'could',
#   'resolve',
#   'issue',
#   '.',
#   'xxxx',
#   'xxxx',
#   ',',
#   '2015',
#   ',',
#   'went',
#   'charter',
#   'one',
#   'bank',
#   'located',
#   ';',
#   'xxxx',
#   'xxxx',
#   'xxxx',
#   'xxxx',
#   'xxxx',
#   ',',
#   'xxxx',
#   ',',
#   'michigan',
#   ',',
#   'xxxx',
#   '.',
#   'told',
#   'branch',
#   'manager',
#   'available',
#   '-',
#   'bank',
#   'teller',
#   'made',
#   'copies',
#   '``',
#   'durable',
#   'power',
#   'attorney',
#   "''",
#   'stated',
#   'would',
#   'forward',
#   'document',
#   'branch',
#   'manager',
#   'following',
#   'day',
#   'resolve',
#   'issue',
#   '.',
#   'xxxx',
#   'xxxx',
#   ',',
#   '2015',
#   ',',
#   'telephoned',
#   'xxxx',
#   'branch',
#   'results',
#   'investigation',
#   'told',
#   'individual',
#   'identified',
#   ':',
#   'xxxx',
#   ',',
#   'branch',
#   'managers',
#   'available',
#   ',',
#   'talked',
#   'representatives',
#   'banking',
#   'headquarters',
#   'would',
#   'telephone',
#   '``',
#   'customer',
#   'service',
#   "''",
#   'along',
#   'mother',
#   'telephone',
#   'resolve',
#   'issue',
#   '.',
#   'informed',
#   'mother',
#   'xxxx',
#   '(',
#   'xxxx',
#   ')',
#   'years',
#   'old',
#   'suffers',
#   '``',
#   'xxxx',
#   'xxxx',
#   'xxxx',
#   "''",
#   'xxxx',
#   'issues',
#   'involved',
#   '.',
#   'offered',
#   'xxxx',
#   'suggestion',
#   'take',
#   'original',
#   '``',
#   'durable',
#   'power',
#   'attorney',
#   "''",
#   'local',
#   'branch',
#   'office',
#   'recording',
#   'placed',
#   'file',
#   '.',
#   'indicated',
#   'already',
#   'done',
#   'years',
#   'ago',
#   'xxxx',
#   'branch',
#   '.',
#   'xxxx',
#   'indicated',
#   'unable',
#   'resolve',
#   'matter',
#   'level',
#   '.',
#   'effort',
#   'resolve',
#   'issue',
#   'without',
#   'problems',
#   ',',
#   'xxxx',
#   'xxxx',
#   ',',
#   '2015',
#   ',',
#   'went',
#   'branch',
#   'office',
#   ';',
#   'xxxx',
#   'xxxx',
#   'xxxx',
#   ',',
#   'xxxx',
#   ',',
#   'michigan',
#   ',',
#   'xxxx',
#   'talked',
#   'xxxx',
#   'xxxx',
#   '.',
#   'indicated',
#   '``',
#   "''",
#   'branch',
#   'manager',
#   'available',
#   'would',
#   'assist',
#   '.',
#   'telephoned',
#   'bank',
#   'headquarters',
#   'told',
#   '``',
#   "''",
#   '``',
#   'durable',
#   'power',
#   'attorney',
#   "''",
#   'file',
#   'mother',
#   "'s",
#   'account',
#   '.',
#   'inconsistencies',
#   'responses',
#   'received',
#   'trying',
#   'resolve',
#   'issue',
#   'charter',
#   'one',
#   'bank',
#   '.',
#   'know',
#   'took',
#   'original',
#   '``',
#   'durable',
#   'power',
#   'attorney',
#   "''",
#   'charter',
#   'one',
#   'bank',
#   'xxxx',
#   ',',
#   'michigan',
#   'xxxx',
#   'years',
#   'ago',
#   'placed',
#   'file',
#   'mother',
#   "'s",
#   'banking',
#   'accounts',
#   '.',
#   'level',
#   '``',
#   'customer',
#   'service',
#   "''",
#   'abysmal',
#   '.'],
#  ['looking',
#   'credit',
#   'report',
#   ',',
#   'saw',
#   'collection',
#   'account',
#   'belong',
#   '.',
#   'allowed',
#   'dispute',
#   'information',
#   'online',
#   'experian',
#   'phone',
#   'making',
#   'impossible',
#   '.',
#   'false',
#   'information',
#   'ruining',
#   'credit',
#   'knowing',
#   'full',
#   'well',
#   'people',
#   'job',
#   'allow',
#   'people',
#   'post',
#   'false',
#   'accounts',
#   'report',
#   '.',
#   'need',
#   'delete',
#   'information',
#   'immediately',
#   'proper',
#   'investigation',
#   'information',
#   'mine',
#   '.'],
#  ['received',
#   'call',
#   'xxxx',
#   'xxxx',
#   'xxxx',
#   '@',
#   'xxxx',
#   'ext',
#   'xxxx',
#   'stating',
#   'owed',
#   '{',
#   '$',
#   '400.00',
#   '}',
#   'xxxx',
#   ',',
#   'wanted',
#   'xxxx',
#   'however',
#   'would',
#   'take',
#   'less',
#   '.',
#   'asked',
#   'validation',
#   'debt',
#   'transferred',
#   'someone',
#   'else',
#   'got',
#   'made',
#   'wanted',
#   'go',
#   'online',
#   '&',
#   'work',
#   '&',
#   'told',
#   'good',
#   'give',
#   'number',
#   '&',
#   'would',
#   'call',
#   'better',
#   'time',
#   '.',
#   'got',
#   'mad',
#   '&',
#   'said',
#   'going',
#   'tell',
#   'debtor',
#   "n't",
#   'want',
#   'pay',
#   '.',
#   'today',
#   'xxxx',
#   'xxxx',
#   ',',
#   '2015',
#   'xxxx',
#   'xxxx',
#   'come',
#   'called',
#   'people',
#   'xxxx',
#   'page',
#   'saying',
#   'used',
#   'reference',
#   '.',
#   'return',
#   'calls',
#   'stated',
#   'going',
#   'make',
#   'complaint',
#   'tactics',
#   '.']]

# %%
porter = PorterStemmer()
snowball = SnowballStemmer('english')
wordnet = WordNetLemmatizer()

docs_porter = [[porter.stem(word) for word in words] for words in docs]
docs_snowball = [[snowball.stem(word) for word in words] for words in docs]
docs_wordnet = [[wordnet.lemmatize(word) for word in words] for words in docs]

# %%
print "%16s %16s %16s %16s" % ("word", "porter", "snowball", "lemmatizer")
for i in xrange(min(len(docs_porter[0]), len(docs_snowball[0]), len(docs_wordnet[0]))):
    p, s, w = docs_porter[0][i], docs_snowball[0][i], docs_wordnet[0][i]
    if len(set((p, s, w))) != 1:
        print "%16s %16s %16s %16s" % (docs[0][i], p, s, w)
# Out:
#             word           porter         snowball       lemmatizer
#         received           receiv           receiv         received
#          capital            capit            capit          capital
#           charge            charg            charg           charge
#          applied            appli            appli          applied
#         accepted           accept           accept         accepted
#        activated            activ            activ        activated
#             used              use              use             used
#           charge            charg            charg           charge
#       activating            activ            activ       activating
#          capital            capit            capit          capital
#          another            anoth            anoth          another
#        activated            activ            activ        activated
#             used              use              use             used
#    non-activated        non-activ        non-activ    non-activated
#             used              use              use             used
#           yearly           yearli             year           yearly
#        activated            activ            activ        activated
#           called             call             call           called
#          charged            charg            charg          charged
#       outrageous           outrag           outrag       outrageous
#           called             call             call           called
#           stated            state            state           stated
#     accidentally         accident         accident     accidentally
#          applied            appli            appli          applied
#        corrected          correct          correct        corrected
#        corrected          correct          correct        corrected
#          applied            appli            appli          applied
#           wanted             want             want           wanted
#       bankruptcy       bankruptci       bankruptci       bankruptcy
#            apply            appli            appli            apply
#         previous          previou         previous         previous
#           stated            state            state           stated
#          charged            charg            charg          charged
#       outrageous           outrag           outrag       outrageous
#        spreading           spread           spread        spreading
#            .this             .thi            .this            .this
#               bs               bs               bs                b
#           called             call             call           called
#         numerous            numer            numer         numerous
#         numerous            numer            numer         numerous
#       correcting          correct          correct       correcting
#     acknowledged       acknowledg       acknowledg     acknowledged
#          mistake           mistak           mistak          mistake
#           wanted             want             want           wanted
#          totally            total            total          totally
#          illegal            illeg            illeg          illegal
#          calling             call             call          calling
#          writing            write            write          writing
#       resolution          resolut          resolut       resolution
#           stated            state            state           stated
#          totally            total            total          totally
#           paying              pay              pay           paying
#             else              els              els             else
#         sometime          sometim          sometim         sometime
#          started            start            start          started
#          getting              get              get          getting
#      threatening         threaten         threaten      threatening
#       collection          collect          collect       collection
#           agency            agenc            agenc           agency
#           really           realli           realli           really
#      threatening         threaten         threaten      threatening
#            every            everi            everi            every
#            ended              end              end            ended
#        extremely           extrem           extrem        extremely
#        hospitals           hospit           hospit         hospital
#        hospitals           hospit           hospit         hospital
#          ..ended            ..end            ..end          ..ended
#           entire            entir            entir           entire
#           freeze            freez            freez           freeze
#        currently          current          current        currently
#          illegal            illeg            illeg          illegal
#           called             call             call           called
#          capital            capit            capit          capital
#          nothing             noth             noth          nothing
#           called             call             call           called
#       etc..asked         etc..ask         etc..ask       etc..asked
#     verification            verif            verif     verification
#          receive           receiv           receiv          receive
#          clearly          clearli            clear          clearly
#          totally            total            total          totally
#        different           differ           differ        different
#          illegal            illeg            illeg          illegal
#        practices          practic          practic         practice
#        regarding           regard           regard        regarding
#          capital            capit            capit          capital
#         recently           recent           recent         recently
#          stating            state            state          stating
#          stating            state            state          stating
#        something           someth           someth        something
#         property         properti         properti         property
#           office            offic            offic           office
#          getting              get              get          getting
#        regarding           regard           regard        regarding
#         property         properti         properti         property
#         property         properti         properti         property
#          nothing             noth             noth          nothing
#          capital            capit            capit          capital
#          totally            total            total          totally
#        illegally            illeg            illeg        illegally
#          screwed            screw            screw          screwed
#          illegal            illeg            illeg          illegal
#       collection          collect          collect       collection
#        practices          practic          practic         practice
#          website           websit           websit          website
#          renewal            renew            renew          renewal
#         previous          previou         previous         previous
#               us               us               us                u
#          getting              get              get          getting
#        harassing           harass           harass        harassing
#      threatening         threaten         threaten      threatening
#          illegal            illeg            illeg          illegal

# %%
my_docs = docs_snowball

# %%
vocab_set = set()
[[vocab_set.add(token) for token in tokens] for tokens in my_docs]
vocab = list(vocab_set)

# %%
vocab_dict = {word: i for i, word in enumerate(vocab)}

# %%
import numpy as np

word_counts = np.zeros((len(docs), len(vocab)))
for doc_id, words in enumerate(my_docs):
    for word in words:
        word_id = vocab_dict[word]
        word_counts[doc_id][word_id] += 1

# %%
df = np.sum(word_counts > 0, axis=0)

# %%
tf_norm = np.sqrt((word_counts ** 2).sum(axis=1))
tf_norm[tf_norm == 0] = 1
tf = word_counts / tf_norm.reshape(len(my_docs), 1)

# %%
idf = np.log((len(my_docs) + 1.) / (1. + df)) + 1.
tfidf = tf * idf

# %%
tfidf_norm = np.sqrt((tfidf ** 2).sum(axis=1))
tfidf_norm[tfidf_norm == 0] = 1
tfidf_normed = tfidf / tfidf_norm.reshape(len(my_docs), 1)

# %% [markdown]
# ### SKLEARN

# %%
def tokenize(doc):
    '''
    INPUT: string
    OUTPUT: list of strings

    Tokenize and stem/lemmatize the document.
    '''
    return [snowball.stem(word) for word in word_tokenize(doc.lower())]

# %%
countvect = CountVectorizer(stop_words='english', tokenizer=tokenize)
count_vectorized = countvect.fit_transform(df_text)

# %%
words = countvect.get_feature_names()
print "sklearn count of 'card':", count_vectorized[0, words.index('card')]
print "my count of 'card':", word_counts[0, vocab_dict['card']]
# Out:
#  sklearn count of 'card':
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-aba6757b421f> in <module>()
#       1 words = countvect.get_feature_names()
# ----> 2 print "sklearn count of 'card':", count_vectorized[0, words.index('card')]
#       3 print "my count of 'card':", word_counts[0, vocab_dict['card']]
#
# ValueError: 'card' is not in list

# %%
tfidfvect = TfidfVectorizer(stop_words='english', tokenizer=tokenize)
tfidf_vectorized = tfidfvect.fit_transform(df_text)

# %%
words_tfidf = tfidfvect.get_feature_names()
print "sklearn tfidf of 'dinner':", tfidf_vectorized[0, words_tfidf.index('dinner')]
print "my tfidf of 'dinner':", tfidf[0, vocab_dict['dinner']]
# Out:
# sklearn tfidf of 'dinner':
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-8c6def64f7ca> in <module>()
#       1 words_tfidf = tfidfvect.get_feature_names()
# ----> 2 print "sklearn tfidf of 'dinner':", tfidf_vectorized[0, words_tfidf.index('dinner')]
#       3 print "my tfidf of 'dinner':", tfidf[0, vocab_dict['dinner']]
#
# ValueError: 'dinner' is not in list
